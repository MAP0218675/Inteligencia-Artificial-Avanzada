# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
spotify_data = pd.read_csv('spotify.csv', encoding='latin1')
pd.set_option('display.max_columns', None)
display(spotify_data.head())
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  Spotify Popularity  \
# 0                 30,716            196,631,588                92.0
# 1                 28,113            174,597,137                92.0
# 2                 54,331            211,607,669                92.0
# 3                269,802            136,569,078                85.0
# 4                  7,223            151,469,874                88.0
#
#    YouTube Views YouTube Likes TikTok Posts   TikTok Likes    TikTok Views  \
# 0     84,274,754     1,713,126    5,767,700    651,565,900   5,332,281,936
# 1    116,347,040     3,486,739      674,700     35,223,547     208,339,025
# 2    122,599,116     2,228,730    3,025,400    275,154,237   3,369,120,610
# 3  1,096,100,899    10,629,796    7,189,811  1,078,757,968  14,603,725,994
# 4     77,373,957     3,670,188       16,400            NaN             NaN
#
#   YouTube Playlist Reach  Apple Music Playlist Count AirPlay Spins  \
# 0            150,597,040                       210.0        40,975
# 1            156,380,351                       188.0        40,778
# 2            373,784,955                       190.0        74,333
# 3          3,351,188,582                       394.0     1,474,799
# 4            112,763,851                       182.0        12,185
#
#   SiriusXM Spins  Deezer Playlist Count Deezer Playlist Reach  \
# 0            684                   62.0            17,598,718
# 1              3                   67.0            10,422,430
# 2            536                  136.0            36,321,847
# 3          2,182                  264.0            24,684,248
# 4              1                   82.0            17,660,624
#
#    Amazon Playlist Count Pandora Streams Pandora Track Stations  \
# 0                  114.0      18,004,655                 22,931
# 1                  111.0       7,780,028                 28,444
# 2                  172.0       5,022,621                  5,639
# 3                  210.0     190,260,277                203,384
# 4                  105.0       4,493,884                  7,006
#
#   Soundcloud Streams Shazam Counts  TIDAL Popularity  Explicit Track
# 0          4,818,457     2,669,262               NaN               0
# 1          6,623,075     1,118,279               NaN               1
# 2          7,208,651     5,285,340               NaN               0
# 3                NaN    11,822,942               NaN               0
# 4            207,179       457,017               NaN               1

# %%
spotify_data.drop(['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC','All Time Rank', 'TIDAL Popularity'], axis=1, inplace=True)

# %%
spotify_d_clean = spotify_data.replace({',': ''}, regex=True)
for col in spotify_d_clean.columns[5:]:
    if spotify_d_clean[col].dtype == 'object':
        spotify_d_clean[col] = spotify_d_clean[col].astype(float)
spotify_d_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track Score                 4600 non-null   float64
#  1   Spotify Streams             4487 non-null   object
#  2   Spotify Playlist Count      4530 non-null   object
#  3   Spotify Playlist Reach      4528 non-null   object
#  4   Spotify Popularity          3796 non-null   float64
#  5   YouTube Views               4292 non-null   float64
#  6   YouTube Likes               4285 non-null   float64
#  7   TikTok Posts                3427 non-null   float64
#  8   TikTok Likes                3620 non-null   float64
#  9   TikTok Views                3619 non-null   float64
#  10  YouTube Playlist Reach      3591 non-null   float64
#  11  Apple Music Playlist Count  4039 non-null   float64
#  12  AirPlay Spins               4102 non-null   float64
#  13  SiriusXM Spins              2477 non-null   float64
#  14  Deezer Playlist Count       3679 non-null   float64
#  15  Deezer Playlist Reach       3672 non-null   float64
#  16  Amazon Playlist Count       3545 non-null   float64
#  17  Pandora Streams             3494 non-null   float64
#  18  Pandora Track Stations      3332 non-null   float64
#  19  Soundcloud Streams          1267 non-null   float64
#  20  Shazam Counts               4023 non-null   float64
#  21  Explicit Track              4600 non-null   int64
# dtypes: float64(18), int64(1), object(3)
# memory usage: 790.8+ KB

# %%
object_columns = spotify_d_clean.select_dtypes(include=['object']).columns
spotify_d_clean[object_columns] = spotify_d_clean[object_columns].apply(pd.to_numeric, errors='coerce')
spotify_d_clean.fillna(spotify_d_clean.median(), inplace = True)

# %% [markdown]
# ### 2. Visualizing Data Distributions

# %%
fig = make_subplots(rows = 1, cols = 2)
columns = ["Spotify Streams", "YouTube Views"]
colors = ["orange", "lightblue"]

for index, column in enumerate(columns):
    fig.add_trace(
        go.Histogram(
            x = spotify_d_clean[column],
            marker = dict(
                color = colors[index],
                line = dict(
                    color = "black",
                    width = 0.2
                )
            ),
            name = column
        ),
        row = 1, col = index + 1,
        
    )

    fig.update_xaxes(
        title = "Número de Reproducciones",
        row = 1, col = index + 1
    )

    fig.update_yaxes(
        title = "Frecuencia (conteo)",
        row = 1, col = index + 1
    )

fig.update_layout(
    template = "plotly_dark",
    title = "Histograma de Spotify Streams e YouTube Views",
)
fig.show()

# %% [markdown]
# ### 3. Measures of Central Tendency

# %%
print(f"Spotify Streams - Media: {spotify_d_clean['Spotify Streams'].mean(): .2f}, Mediana: {spotify_d_clean['Spotify Streams'].median(): .2f}")
print(f"YouTube Views- Media: {spotify_d_clean['YouTube Views'].mean(): .2f}, Mediana: {spotify_d_clean['YouTube Views'].median(): .2f}")
# Out:
# Spotify Streams - Media:  442289133.18, Mediana:  239850720.00
# YouTube Views- Media:  385754478.40, Mediana:  148269610.00

# %% [markdown]
# 4. Measures of Central Tendency

# %%
columns_measures = ["Spotify Streams", "YouTube Views", "Spotify Popularity"]
data_measures = spotify_d_clean[columns_measures]

# %%
for column in columns_measures:
    mean = data_measures[column].mean()
    std = data_measures[column].std()
    cv = std / mean
    print("-"*len(data_measures[column]))
    print(f"{column} - Des  viación estándar: {std: .2f}, Coeficiente de variación: {cv: .2f}")
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# Spotify Streams - Deviación estándar:  532757533.72, Coeficiente de variación:  1.20
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# YouTube Views - Deviación estándar:  680968100.19, Coeficiente de variación:  1.77
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# Spotify Popularity - Deviación estándar:  14.76, Coeficiente de variación:  0.23

# %% [markdown]
# # Parte 2

# %% [markdown]
# ### Defining Events

# %%
spotify_d_clean["high_popularity"] = spotify_d_clean["Spotify Popularity"].map(lambda row: "The song has High Popularity" if row >= 85 else " The song has Low Popularity")

# %%
spotify_d_clean["is_explicit"] = spotify_d_clean["Explicit Track"].map(lambda row: "The song is Explicit" if row == 1 else "The song is Not Explicit")

# %% [markdown]
# ### 2. Calculating Prior Probabilities

# %%
p_a = sum(spotify_d_clean["high_popularity"] == "The song has High Popularity") / len(spotify_d_clean["high_popularity"]) 
p_b = sum(spotify_d_clean["is_explicit"] == "The song is Explicit") / len(spotify_d_clean["is_explicit"])
p_a_and_b = sum((spotify_d_clean["high_popularity"] == "The song has High Popularity") & (spotify_d_clean["is_explicit"] == "The song is Explicit")) / len(spotify_d_clean)

p_a_given_b = p_a_and_b / p_b

# %%
print(f"P(A) = {p_a: .4f}")
print(f"P(B) = {p_b: .4f}")
print(f"P(A | B) = {p_a_given_b: .4f}")
# Out:
# P(A) =  0.0117
# P(B) =  0.3589
# P(A | B) =  0.0109

# %% [markdown]
# ### 3. Applying Bayes' Theorem

# %%
p_b_given_a = p_a_and_b / p_a

# %%
bayes_b_given_a = (p_a_given_b * p_b)/p_a

# %%
print(f"P(B | A) = {bayes_b_given_a:.4f}")
# Out:
# P(B | A) = 0.3333

# %%
print(f"P(B | A) = {p_b_given_a: .4f}")
# Out:
# P(B | A) =  0.3333
